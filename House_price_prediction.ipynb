# %%
import numpy as np
import pandas as pd
import math
# Out:
# C:\Users\ranji\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\ranji\OneDrive\Desktop\House price prediction\House_clean.csv")

# %%
df
# Out:
#        Year  Sqft  Bedrooms  Bathrooms  Floors    Price
# 0      1921  3650         5          3       2  2380000
# 1      1909  2920         4          3       2  1400000
# 2      1939  2910         5          3       2  1200000
# 3      2001  3310         4          3       2   838000
# 4      1929  2710         3          2       2   805000
# ...     ...   ...       ...        ...     ...      ...
# 14615  1957  1556         2          2       1   221700
# 14616  1968  1680         3          2       2   219200
# 14617  1962  1070         2          1       1   209000
# 14618  1955  1030         4          1       1   205000
# 14619  1969   900         3          1       1   146000
#
# [14620 rows x 6 columns]

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       14620 non-null  int64
#  1   Sqft       14620 non-null  int64
#  2   Bedrooms   14620 non-null  int64
#  3   Bathrooms  14620 non-null  int64
#  4   Floors     14620 non-null  int64
#  5   Price      14620 non-null  int64
# dtypes: int64(6)
# memory usage: 685.4 KB

# %%
#check null values
df.isnull().sum()
# Out:
# Year         0
# Sqft         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# Price        0
# dtype: int64

# %%
#check duplicates
df.duplicated().sum()
# Out:
# 24

# %%
#drop duplicatesabs
df.drop_duplicates()
# Out:
#        Year  Sqft  Bedrooms  Bathrooms  Floors    Price
# 0      1921  3650         5          3       2  2380000
# 1      1909  2920         4          3       2  1400000
# 2      1939  2910         5          3       2  1200000
# 3      2001  3310         4          3       2   838000
# 4      1929  2710         3          2       2   805000
# ...     ...   ...       ...        ...     ...      ...
# 14615  1957  1556         2          2       1   221700
# 14616  1968  1680         3          2       2   219200
# 14617  1962  1070         2          1       1   209000
# 14618  1955  1030         4          1       1   205000
# 14619  1969   900         3          1       1   146000
#
# [14596 rows x 6 columns]

# %%
X = df.drop('Price', axis = 1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#scaling
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
ss.fit(df)
# Out:
# StandardScaler()

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression

# Random Forest Regression
from sklearn.ensemble import RandomForestRegressor

# Gradient Boosting Regressor (XGBoost)
from xgboost import XGBRegressor

# Support Vector Regression (SVR)
from sklearn.svm import SVR

# K-Nearest Neighbors (KNN)
from sklearn.neighbors import KNeighborsRegressor

# %%
lr=LinearRegression()
rfr=RandomForestRegressor()
boost=XGBRegressor()
svr=SVR()
knn=KNeighborsRegressor()

# %%
#automate our prediction 
algos=[lr,rfr,boost,svr,knn]
algos_name=['LinearRegression','RandomForestRegressor','XGBRegressor','SVR','KNeighborsRegressor']

# %%
 from sklearn.metrics import accuracy_score

# %%
for algo, algo_name in zip(algos, algos_name):
    algo.fit(X_train, y_train)
    y_pred = algo.predict(X_test)
    accuracy = algo.score(X_test, y_test) * 100
    print(algo_name)
    print(accuracy)
    print("=" * 50)
# Out:
# LinearRegression
# 57.14132095268312
# ==================================================
# RandomForestRegressor
# 58.51189863436399
# ==================================================
# XGBRegressor
# 55.299059993649735
# ==================================================
# SVR
# -5.892935492713858
# ==================================================
# KNeighborsRegressor
# 55.624021647852054
# ==================================================

# %%
y_pred = rfr.predict(X_test)

# %%
y_pred
# Out:
# array([363279.08, 324119.1 , 473420.9 , ..., 951986.76, 263552.5 ,
#        660308.65])

# %%
inputmodel=pd.DataFrame([[1921,3650,5,3,2]],columns=['Year','Sqft','Bedrooms','Bathrooms','Floors'])

# %%
inputmodel
# Out:
#    Year  Sqft  Bedrooms  Bathrooms  Floors
# 0  1921  3650         5          3       2

# %%
boost.predict(inputmodel)
# Out:
# array([2038988.], dtype=float32)

# %%
import pickle as pk

# %%
pk.dump(boost,open('house.pkl','wb'))
